# %% [markdown]
# __Assignment3__
#
# **Q4. Dataset Understanding (Titanic Dataset)**
#
#
# Context: First step in ML pipeline is dataset inspection.
#
# Dataset: Titanic (Seaborn)
#
# Tasks:
#
# 1. Display: head(), tail() info(), describe()
# 2. Identify: Missing values per column Numerical vs categorical features
# 3. Explain: Why identifying feature types is important before modeling

# %%
#Display: head(), tail() info(), describe()
import seaborn as sns
import pandas as pd
titanicDataSet = sns.load_dataset("titanic")
#print(titanicDataSet)
#titanicDataSet.head(2)
titanicDataSet.head()
titanicDataSet.tail()
titanicDataSet.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#2: Identify: Missing values per column Numerical vs categorical features

import seaborn as sns
import pandas as pd
titanicDataSet = sns.load_dataset("titanic")
missingValues = titanicDataSet.isnull().sum()
print(missingValues)
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#3.Explain: Why identifying feature types is important before modeling
Identifying the feature type is important to know whether the feature is numeracal or categorical type. Depending on the feature type it requires the 
different preprocessing. During the preprocessing, we will remove null values, and filter the data data based on the mean of the certain feature types.
